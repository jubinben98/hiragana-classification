# %%
# !wget "http://codh.rois.ac.jp/kmnist/dataset/k49/k49-train-imgs.npz"
# !wget "http://codh.rois.ac.jp/kmnist/dataset/k49/k49-train-labels.npz"
# !wget "http://codh.rois.ac.jp/kmnist/dataset/k49/k49-test-imgs.npz"
# !wget "http://codh.rois.ac.jp/kmnist/dataset/k49/k49-test-labels.npz"
# !wget "http://codh.rois.ac.jp/kmnist/dataset/k49/k49_classmap.csv"
# Out:
# --2023-10-01 05:16:00--  http://codh.rois.ac.jp/kmnist/dataset/k49/k49-train-imgs.npz
# Resolving codh.rois.ac.jp (codh.rois.ac.jp)... 136.187.88.58
# Connecting to codh.rois.ac.jp (codh.rois.ac.jp)|136.187.88.58|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66117696 (63M)
# Saving to: ‘k49-train-imgs.npz’
#
# k49-train-imgs.npz  100%[===================>]  63.05M  1.26MB/s    in 47s
#
# 2023-10-01 05:16:48 (1.33 MB/s) - ‘k49-train-imgs.npz’ saved [66117696/66117696]
#
# --2023-10-01 05:16:48--  http://codh.rois.ac.jp/kmnist/dataset/k49/k49-train-labels.npz
# Resolving codh.rois.ac.jp (codh.rois.ac.jp)... 136.187.88.58
# Connecting to codh.rois.ac.jp (codh.rois.ac.jp)|136.187.88.58|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 164485 (161K)
# Saving to: ‘k49-train-labels.npz’
#
# k49-train-labels.np 100%[===================>] 160.63K   363KB/s    in 0.4s
#
# 2023-10-01 05:16:49 (363 KB/s) - ‘k49-train-labels.npz’ saved [164485/164485]
#
# --2023-10-01 05:16:49--  http://codh.rois.ac.jp/kmnist/dataset/k49/k49-test-imgs.npz
# Resolving codh.rois.ac.jp (codh.rois.ac.jp)... 136.187.88.58
# Connecting to codh.rois.ac.jp (codh.rois.ac.jp)|136.187.88.58|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10971201 (10M)
# Saving to: ‘k49-test-imgs.npz’
#
# k49-test-imgs.npz   100%[===================>]  10.46M   994KB/s    in 11s
#
# 2023-10-01 05:17:00 (955 KB/s) - ‘k49-test-imgs.npz’ saved [10971201/10971201]
#
# --2023-10-01 05:17:00--  http://codh.rois.ac.jp/kmnist/dataset/k49/k49-test-labels.npz
# Resolving codh.rois.ac.jp (codh.rois.ac.jp)... 136.187.88.58
# Connecting to codh.rois.ac.jp (codh.rois.ac.jp)|136.187.88.58|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27450 (27K)
# Saving to: ‘k49-test-labels.npz’
#
# k49-test-labels.npz 100%[===================>]  26.81K  --.-KB/s    in 0.1s
#
# 2023-10-01 05:17:01 (184 KB/s) - ‘k49-test-labels.npz’ saved [27450/27450]
#
# --2023-10-01 05:17:01--  http://codh.rois.ac.jp/kmnist/dataset/k49/k49_classmap.csv
# Resolving codh.rois.ac.jp (codh.rois.ac.jp)... 136.187.88.58
# Connecting to codh.rois.ac.jp (codh.rois.ac.jp)|136.187.88.58|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 697 [text/csv]
# Saving to: ‘k49_classmap.csv’
#
# k49_classmap.csv    100%[===================>]     697  --.-KB/s    in 0s
#
# 2023-10-01 05:17:01 (61.2 MB/s) - ‘k49_classmap.csv’ saved [697/697]

# %%
pip install japanize_matplotlib
# Out:
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from japanize_matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.16.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=3da22ba00c04a5470fbb4db753736a6597dc3948300aed57c88dfc7727fc08e6
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize_matplotlib
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3

# %%
import cv2 as cv
import numpy as np
import pandas as pd
import random
import pickle
import time
import japanize_matplotlib
import tensorflow as tf

from google.colab import files
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from IPython.display import display, clear_output
from typing import List

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %% [markdown]
# ### Loading the data

# %%
# Loading the train data
images = np.load('k49-train-imgs.npz')['arr_0']
labels = np.load('k49-train-labels.npz')['arr_0']

# Loading the test
test_images = np.load("k49-test-imgs.npz")['arr_0']
test_labels = np.load("k49-test-labels.npz")['arr_0']

print("Train data: ", images.shape, labels.shape)
print("Test data: ", test_images.shape, test_labels.shape)
# Out:
# Train data:  (232365, 28, 28) (232365,)
# Test data:  (38547, 28, 28) (38547,)

# %%
# Loading the class mapping
class_map = np.array(pd.read_csv("k49_classmap.csv")['char'])
class_map
# Out:
# array(['あ', 'い', 'う', 'え', 'お', 'か', 'き', 'く', 'け', 'こ', 'さ', 'し', 'す',
#        'せ', 'そ', 'た', 'ち', 'つ', 'て', 'と', 'な', 'に', 'ぬ', 'ね', 'の', 'は',
#        'ひ', 'ふ', 'へ', 'ほ', 'ま', 'み', 'む', 'め', 'も', 'や', 'ゆ', 'よ', 'ら',
#        'り', 'る', 'れ', 'ろ', 'わ', 'ゐ', 'ゑ', 'を', 'ん', 'ゝ'], dtype=object)

# %%
# Checking the number of classes
NUM_CLASSES = len(np.unique(labels))

# Checking if the labels inside training data and testing data are the same
assert len(set(np.unique(labels)).difference(set(np.unique(test_labels)))) == 0

print("Number of unique classes: ", NUM_CLASSES)
# Out:
# Number of unique classes:  49

# %% [markdown]
# ### Checking the distribution of the data

# %%
plt.figure(figsize=(15, 5))
plt.bar(np.unique(labels), np.bincount(labels), tick_label=[str(i) for i in range(NUM_CLASSES)])
plt.title("Category distribution")
plt.xlabel("Hiragana Letters Indexes")
plt.ylabel("Number of elements")
# Out:
# Text(0, 0.5, 'Number of elements')

# %% [markdown]
# From the above plot, we can observe a clear data imbalance, specifically for class 3, 44 and 45. So, we will perform some data augmentations to generate new data from the existing data.

# %% [markdown]
# ### Data Augmentation

# %%
def augment_images(images: List[np.ndarray], n: int) -> List[np.ndarray]:
    """
    Augments a list of grayscale images by applying various transformations.

    Parameters:
        images (List[np.ndarray]): List of input grayscale images.
        n (int): Number of augmentations to generate per input image.

    Returns:
        List[np.ndarray]: List of augmented grayscale images.
    """
    # Create an image data generator with specified augmentation settings
    augmenter = ImageDataGenerator(
        rotation_range=10,
        zoom_range=0.3,
        width_shift_range=0.3,
        fill_mode='constant'
    )

    augmented_images = []
    for image in images:
        # Convert grayscale to BGR
        color_image = cv.cvtColor(image, cv.COLOR_GRAY2BGR)
        # Generate augmented images
        augmented_generator = augmenter.flow(np.array([color_image] * n))
        # Convert augmented images back to grayscale and add to the list
        augmented_images.extend([cv.cvtColor(augmented, cv.COLOR_BGR2GRAY) for augmented in next(augmented_generator)])

    return augmented_images

# %%
# Visualization of the augment_images

_image = images[10]
_augumented_image = augment_images([_image], 3)

_, ax = plt.subplots(1, 4, figsize=(10, 5))
ax[0].imshow(_image)
ax[0].title.set_text("Original Image")

ax[1].imshow(_augumented_image[0])
ax[2].imshow(_augumented_image[1])
ax[3].imshow(_augumented_image[2])

plt.show()

# %% [markdown]
# ### Data Preprocessing
#
# Since our data have heavy imbalance below prcess will serves the purpose of balancing an image dataset, along with their associated labels, to create a well-rounded training set for machine learning:
#
# #### The process executes as follows:
#
# - For each distinct label in the dataset:
#   - Accumulate all images belonging to the current label's class.
#   - In case the count of images for the current class falls short of a predetermined threshold (`CATEGORY_DATA_LEN`), the code embarks on an augmentation process. This involves employing the augment_images function to produce augmented versions of these images.
#   - `AUGMENTATION_SAMPLES` defines the number of augmented images to be generated for a single image.
#   - Meld the original images with the augmented ones to achieve a total of `CATEGORY_DATA_LEN` samples for the class.
#   - Append the processed images to the `X_train` array.
#   - Corresponding to these images, append labels to the `y_train` array, replicating the current class label as needed.
#
# This process essentially targets the issue of class imbalance by generating extra instances for classes that have an insufficient representation. The result is a meticulously balanced dataset that is well-suited for training machine learning models.

# %% [markdown]
# ##### Data Augmentation

# %%
CATEGORY_DATA_LEN = 6000
AUGMENTATION_SAMPLES = 2

# Initialize arrays for training images and labels
X_train = np.empty((0, 28, 28), np.uint8)
y_train = np.empty((0), int)

# Iterate through unique labels in the dataset
for i in np.unique(labels):
    # Extract images belonging to the current class
    class_images = images[np.where(labels == i)[0]]
    # Check if the current class has fewer images than required amount
    if len(class_images) < CATEGORY_DATA_LEN:
        while len(class_images) <= CATEGORY_DATA_LEN:
          # Augment images
          augumented_images = augment_images(class_images, AUGMENTATION_SAMPLES)
          # Calculate the number of additional images needed
          images_needed = CATEGORY_DATA_LEN - len(class_images)
          # Combine original and augmented images
          class_images = np.concatenate([class_images, augumented_images], axis=0)

    # Combining existing images and augmented images
    X_train = np.concatenate([X_train, class_images[:CATEGORY_DATA_LEN]], axis=0)  # Append images to X_train
    y_train = np.concatenate([y_train, np.repeat(i, CATEGORY_DATA_LEN)])  # Append labels to y_train

assert X_train.shape[0] == y_train.shape[0]
print("Total Data for training: ", X_train.shape, y_train.shape)
# Out:
# Total Data for training:  (294000, 28, 28) (294000,)

# %%
# Updated distribution

plt.figure(figsize=(15, 3))
plt.bar(np.unique(y_train), np.bincount(y_train), tick_label=[str(i) for i in range(NUM_CLASSES)])
plt.title("Category distribution")
plt.xlabel("Hiragana Letters Indexes")
plt.ylabel("Number of elements")
# Out:
# Text(0, 0.5, 'Number of elements')

# %% [markdown]
# #### Train and validation split

# %%
# Shuffle the data
indices = np.arange(X_train.shape[0])
np.random.shuffle(indices)

X_train = np.array(X_train[indices])
y_train = np.array(y_train[indices])

# Train and Validation split
split_80 = int(X_train.shape[0]*0.80)

X_valid = X_train[split_80:]
y_valid = y_train[split_80:]

X_train = X_train[:split_80]
y_train = y_train[:split_80]


print("Train data: ", X_train.shape, y_train.shape)
print("Validation data: ", X_valid.shape, y_valid.shape)
# Out:
# Train data:  (235200, 28, 28) (235200,)
# Validation data:  (58800, 28, 28) (58800,)

# %% [markdown]
# #### Data Normalization and Label transformation

# %%
def x_norm_y_transform(X, y):
    """
    Normalize input data and transform labels to one-hot encoding.
    Parameters:
        X (numpy.ndarray): Input data.
        y (numpy.ndarray): Labels.
    Returns:
        numpy.ndarray, numpy.ndarray: Normalized data, one-hot encoded labels.
    """
    # Normalize input data by dividing by 255
    X_normalized = X / 255
    # Transform labels to one-hot encoding
    y_one_hot = to_categorical(y)
    return X_normalized, y_one_hot

X_test, y_test = x_norm_y_transform(test_images, test_labels)
X_valid, y_valid = x_norm_y_transform(X_valid, y_valid)
X_train, y_train = x_norm_y_transform(X_train, y_train)

# %% [markdown]
# ### Building the model
#
#  We will be using a simple sequential deep learning model for Hiragana letter classification.
#
#  The model architecture consists of fully connected layers followed by batch normalization to enhance training stability. The last layer utilizes softmax activation to predict among 49 classes,

# %%
def build_seq_model():
  """
  Build a sequential deep learning model for
  Hiragana letter classification.

  Returns:
      tf.keras.Model: Constructed sequential model.
  """
  model = tf.keras.Sequential([
      tf.keras.Input(shape=(28, 28)),
      tf.keras.layers.Conv1D(kernel_size=3, filters=32, padding='same', activation='relu'),
      tf.keras.layers.Conv1D(kernel_size=3, filters=32, padding='same', activation='relu'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.MaxPooling1D(pool_size=2),

      tf.keras.layers.Conv1D(kernel_size=3, filters=64, padding='same', activation='relu'),
      tf.keras.layers.Conv1D(kernel_size=3, filters=64, padding='same', activation='relu'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.MaxPooling1D(pool_size=2),

      tf.keras.layers.Conv1D(kernel_size=3, filters=128, padding='same', activation='relu'),
      tf.keras.layers.Conv1D(kernel_size=3, filters=128, padding='same', activation='relu'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.MaxPooling1D(pool_size=2),

      tf.keras.layers.Conv1D(kernel_size=3, filters=512, padding='same', activation='relu'),
      tf.keras.layers.Conv1D(kernel_size=3, filters=512, padding='same', activation='relu'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.MaxPooling1D(pool_size=2),

      tf.keras.layers.Conv1D(kernel_size=3, filters=128, padding='same', activation='relu'),
      tf.keras.layers.Conv1D(kernel_size=3, filters=128, padding='same', activation='relu'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.BatchNormalization(),

      tf.keras.layers.GlobalAveragePooling1D(),

      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),

      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),

      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dropout(0.1),

      tf.keras.layers.Dense(49, activation='softmax')
  ])

  return model

# %%
# Model summary
print("Model Summary: ", build_seq_model().summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_54 (Conv1D)          (None, 28, 32)            2720
#
#  conv1d_55 (Conv1D)          (None, 28, 32)            3104
#
#  dropout_33 (Dropout)        (None, 28, 32)            0
#
#  batch_normalization_31 (Bat  (None, 28, 32)           128
#  chNormalization)
#
#  max_pooling1d_26 (MaxPoolin  (None, 14, 32)           0
#  g1D)
#
#  conv1d_56 (Conv1D)          (None, 14, 64)            6208
#
#  conv1d_57 (Conv1D)          (None, 14, 64)            12352
#
#  dropout_34 (Dropout)        (None, 14, 64)            0
#
#  batch_normalization_32 (Bat  (None, 14, 64)           256
#  chNormalization)
#
#  max_pooling1d_27 (MaxPoolin  (None, 7, 64)            0
#  g1D)
#
#  conv1d_58 (Conv1D)          (None, 7, 128)            24704
#
#  conv1d_59 (Conv1D)          (None, 7, 128)            49280
#
#  dropout_35 (Dropout)        (None, 7, 128)            0
#
#  batch_normalization_33 (Bat  (None, 7, 128)           512
#  chNormalization)
#
#  max_pooling1d_28 (MaxPoolin  (None, 3, 128)           0
#  g1D)
#
#  conv1d_60 (Conv1D)          (None, 3, 512)            197120
#
#  conv1d_61 (Conv1D)          (None, 3, 512)            786944
#
#  dropout_36 (Dropout)        (None, 3, 512)            0
#
#  batch_normalization_34 (Bat  (None, 3, 512)           2048
#  chNormalization)
#
#  max_pooling1d_29 (MaxPoolin  (None, 1, 512)           0
#  g1D)
#
#  conv1d_62 (Conv1D)          (None, 1, 128)            196736
#
#  conv1d_63 (Conv1D)          (None, 1, 128)            49280
#
#  dropout_37 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_35 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  global_average_pooling1d_3   (None, 128)              0
#  (GlobalAveragePooling1D)
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dropout_38 (Dropout)        (None, 128)               0
#
#  batch_normalization_36 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dropout_39 (Dropout)        (None, 128)               0
#
#  batch_normalization_37 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_40 (Dropout)        (None, 64)                0
#
#  dense_11 (Dense)            (None, 49)                3185
#
# =================================================================
# Total params: 1,377,393
# Trainable params: 1,375,153
# Non-trainable params: 2,240
# _________________________________________________________________
# Model Summary:  None

# %% [markdown]
# ### Model Training

# %%
# Train config
EPOCHS = 150
BATCH_SIZE = 128*16

# %% [markdown]
# #### TPU Strategy

# %%
strategy = tf.distribute.TPUStrategy(resolver)
with strategy.scope():
  # Building the model
  model = build_seq_model()
  # Compiling the model
  model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Model fit
model_hist = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/150
# 115/115 [==============================] - 29s 108ms/step - loss: 3.4031 - accuracy: 0.1354 - val_loss: 4.1682 - val_accuracy: 0.0310
# Epoch 2/150
# 115/115 [==============================] - 4s 32ms/step - loss: 2.2180 - accuracy: 0.4025 - val_loss: 2.7114 - val_accuracy: 0.3006
# Epoch 3/150
# 115/115 [==============================] - 4s 35ms/step - loss: 1.5515 - accuracy: 0.5891 - val_loss: 1.3609 - val_accuracy: 0.6455
# Epoch 4/150
# 115/115 [==============================] - 4s 33ms/step - loss: 1.1842 - accuracy: 0.6974 - val_loss: 0.9326 - val_accuracy: 0.7645
# Epoch 5/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.9702 - accuracy: 0.7569 - val_loss: 0.6804 - val_accuracy: 0.8243
# Epoch 6/150
# 115/115 [==============================] - 5s 45ms/step - loss: 0.8363 - accuracy: 0.7937 - val_loss: 0.5507 - val_accuracy: 0.8592
# Epoch 7/150
# 115/115 [==============================] - 6s 51ms/step - loss: 0.7394 - accuracy: 0.8199 - val_loss: 0.5041 - val_accuracy: 0.8721
# Epoch 8/150
# 115/115 [==============================] - 5s 44ms/step - loss: 0.6701 - accuracy: 0.8388 - val_loss: 0.4303 - val_accuracy: 0.8915
# Epoch 9/150
# 115/115 [==============================] - 6s 49ms/step - loss: 0.6156 - accuracy: 0.8519 - val_loss: 0.4201 - val_accuracy: 0.8928
# Epoch 10/150
# 115/115 [==============================] - 10s 83ms/step - loss: 0.5699 - accuracy: 0.8639 - val_loss: 0.4173 - val_accuracy: 0.8950
# Epoch 11/150
# 115/115 [==============================] - 8s 67ms/step - loss: 0.5359 - accuracy: 0.8721 - val_loss: 0.3774 - val_accuracy: 0.9044
# Epoch 12/150
# 115/115 [==============================] - 6s 51ms/step - loss: 0.5011 - accuracy: 0.8811 - val_loss: 0.3635 - val_accuracy: 0.9077
# Epoch 13/150
# 115/115 [==============================] - 6s 56ms/step - loss: 0.4798 - accuracy: 0.8857 - val_loss: 0.3422 - val_accuracy: 0.9132
# Epoch 14/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.4561 - accuracy: 0.8917 - val_loss: 0.3299 - val_accuracy: 0.9162
# Epoch 15/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.4337 - accuracy: 0.8966 - val_loss: 0.3431 - val_accuracy: 0.9145
# Epoch 16/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.4172 - accuracy: 0.9007 - val_loss: 0.3074 - val_accuracy: 0.9231
# Epoch 17/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.4033 - accuracy: 0.9047 - val_loss: 0.3050 - val_accuracy: 0.9228
# Epoch 18/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.3893 - accuracy: 0.9080 - val_loss: 0.2881 - val_accuracy: 0.9266
# Epoch 19/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.3762 - accuracy: 0.9106 - val_loss: 0.2968 - val_accuracy: 0.9262
# Epoch 20/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.3631 - accuracy: 0.9136 - val_loss: 0.2727 - val_accuracy: 0.9325
# Epoch 21/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.3520 - accuracy: 0.9173 - val_loss: 0.2628 - val_accuracy: 0.9344
# Epoch 22/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.3447 - accuracy: 0.9181 - val_loss: 0.2631 - val_accuracy: 0.9353
# Epoch 23/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.3330 - accuracy: 0.9210 - val_loss: 0.2521 - val_accuracy: 0.9369
# Epoch 24/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.3268 - accuracy: 0.9218 - val_loss: 0.2571 - val_accuracy: 0.9368
# Epoch 25/150
# 115/115 [==============================] - 4s 38ms/step - loss: 0.3178 - accuracy: 0.9241 - val_loss: 0.2495 - val_accuracy: 0.9390
# Epoch 26/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.3127 - accuracy: 0.9260 - val_loss: 0.2377 - val_accuracy: 0.9419
# Epoch 27/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.3020 - accuracy: 0.9286 - val_loss: 0.2430 - val_accuracy: 0.9405
# Epoch 28/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.2944 - accuracy: 0.9300 - val_loss: 0.2366 - val_accuracy: 0.9413
# Epoch 29/150
# 115/115 [==============================] - 5s 43ms/step - loss: 0.2880 - accuracy: 0.9315 - val_loss: 0.2402 - val_accuracy: 0.9410
# Epoch 30/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.2837 - accuracy: 0.9325 - val_loss: 0.2338 - val_accuracy: 0.9429
# Epoch 31/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.2771 - accuracy: 0.9338 - val_loss: 0.2248 - val_accuracy: 0.9448
# Epoch 32/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.2729 - accuracy: 0.9352 - val_loss: 0.2308 - val_accuracy: 0.9434
# Epoch 33/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.2693 - accuracy: 0.9357 - val_loss: 0.2194 - val_accuracy: 0.9458
# Epoch 34/150
# 115/115 [==============================] - 5s 43ms/step - loss: 0.2660 - accuracy: 0.9366 - val_loss: 0.2407 - val_accuracy: 0.9392
# Epoch 35/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.2590 - accuracy: 0.9378 - val_loss: 0.2241 - val_accuracy: 0.9451
# Epoch 36/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.2556 - accuracy: 0.9388 - val_loss: 0.2201 - val_accuracy: 0.9460
# Epoch 37/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.2497 - accuracy: 0.9400 - val_loss: 0.2188 - val_accuracy: 0.9462
# Epoch 38/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.2432 - accuracy: 0.9419 - val_loss: 0.2063 - val_accuracy: 0.9496
# Epoch 39/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.2446 - accuracy: 0.9420 - val_loss: 0.2228 - val_accuracy: 0.9453
# Epoch 40/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.2397 - accuracy: 0.9429 - val_loss: 0.2098 - val_accuracy: 0.9483
# Epoch 41/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.2344 - accuracy: 0.9434 - val_loss: 0.2214 - val_accuracy: 0.9460
# Epoch 42/150
# 115/115 [==============================] - 4s 36ms/step - loss: 0.2333 - accuracy: 0.9440 - val_loss: 0.2066 - val_accuracy: 0.9488
# Epoch 43/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.2267 - accuracy: 0.9460 - val_loss: 0.1962 - val_accuracy: 0.9521
# Epoch 44/150
# 115/115 [==============================] - 3s 30ms/step - loss: 0.2235 - accuracy: 0.9465 - val_loss: 0.1943 - val_accuracy: 0.9528
# Epoch 45/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.2220 - accuracy: 0.9469 - val_loss: 0.2118 - val_accuracy: 0.9483
# Epoch 46/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.2196 - accuracy: 0.9473 - val_loss: 0.1989 - val_accuracy: 0.9509
# Epoch 47/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.2164 - accuracy: 0.9478 - val_loss: 0.1922 - val_accuracy: 0.9530
# Epoch 48/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.2143 - accuracy: 0.9485 - val_loss: 0.2215 - val_accuracy: 0.9454
# Epoch 49/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.2121 - accuracy: 0.9490 - val_loss: 0.2018 - val_accuracy: 0.9518
# Epoch 50/150
# 115/115 [==============================] - 6s 50ms/step - loss: 0.2067 - accuracy: 0.9503 - val_loss: 0.2136 - val_accuracy: 0.9484
# Epoch 51/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.2043 - accuracy: 0.9505 - val_loss: 0.1988 - val_accuracy: 0.9515
# Epoch 52/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.2022 - accuracy: 0.9511 - val_loss: 0.1905 - val_accuracy: 0.9543
# Epoch 53/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.2012 - accuracy: 0.9515 - val_loss: 0.1962 - val_accuracy: 0.9529
# Epoch 54/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1963 - accuracy: 0.9522 - val_loss: 0.2106 - val_accuracy: 0.9499
# Epoch 55/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1976 - accuracy: 0.9520 - val_loss: 0.2049 - val_accuracy: 0.9513
# Epoch 56/150
# 115/115 [==============================] - 4s 38ms/step - loss: 0.1935 - accuracy: 0.9530 - val_loss: 0.2054 - val_accuracy: 0.9503
# Epoch 57/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1934 - accuracy: 0.9533 - val_loss: 0.1974 - val_accuracy: 0.9519
# Epoch 58/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1899 - accuracy: 0.9541 - val_loss: 0.1922 - val_accuracy: 0.9535
# Epoch 59/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1863 - accuracy: 0.9547 - val_loss: 0.1890 - val_accuracy: 0.9549
# Epoch 60/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1858 - accuracy: 0.9553 - val_loss: 0.1886 - val_accuracy: 0.9552
# Epoch 61/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1843 - accuracy: 0.9553 - val_loss: 0.1921 - val_accuracy: 0.9536
# Epoch 62/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1810 - accuracy: 0.9559 - val_loss: 0.1837 - val_accuracy: 0.9553
# Epoch 63/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1825 - accuracy: 0.9560 - val_loss: 0.1857 - val_accuracy: 0.9552
# Epoch 64/150
# 115/115 [==============================] - 5s 46ms/step - loss: 0.1800 - accuracy: 0.9564 - val_loss: 0.1872 - val_accuracy: 0.9546
# Epoch 65/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1779 - accuracy: 0.9570 - val_loss: 0.1862 - val_accuracy: 0.9556
# Epoch 66/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1770 - accuracy: 0.9568 - val_loss: 0.1888 - val_accuracy: 0.9545
# Epoch 67/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1750 - accuracy: 0.9574 - val_loss: 0.1848 - val_accuracy: 0.9561
# Epoch 68/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1731 - accuracy: 0.9581 - val_loss: 0.1853 - val_accuracy: 0.9562
# Epoch 69/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1694 - accuracy: 0.9588 - val_loss: 0.1817 - val_accuracy: 0.9571
# Epoch 70/150
# 115/115 [==============================] - 3s 30ms/step - loss: 0.1679 - accuracy: 0.9587 - val_loss: 0.1844 - val_accuracy: 0.9562
# Epoch 71/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1658 - accuracy: 0.9593 - val_loss: 0.1936 - val_accuracy: 0.9543
# Epoch 72/150
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1651 - accuracy: 0.9597 - val_loss: 0.1785 - val_accuracy: 0.9569
# Epoch 73/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1681 - accuracy: 0.9590 - val_loss: 0.1748 - val_accuracy: 0.9588
# Epoch 74/150
# 115/115 [==============================] - 3s 30ms/step - loss: 0.1611 - accuracy: 0.9605 - val_loss: 0.1766 - val_accuracy: 0.9577
# Epoch 75/150
# 115/115 [==============================] - 3s 30ms/step - loss: 0.1642 - accuracy: 0.9598 - val_loss: 0.1896 - val_accuracy: 0.9538
# Epoch 76/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1613 - accuracy: 0.9602 - val_loss: 0.1797 - val_accuracy: 0.9573
# Epoch 77/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1583 - accuracy: 0.9616 - val_loss: 0.1752 - val_accuracy: 0.9592
# Epoch 78/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1588 - accuracy: 0.9610 - val_loss: 0.1855 - val_accuracy: 0.9569
# Epoch 79/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1557 - accuracy: 0.9618 - val_loss: 0.1949 - val_accuracy: 0.9547
# Epoch 80/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1551 - accuracy: 0.9621 - val_loss: 0.1953 - val_accuracy: 0.9538
# Epoch 81/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1541 - accuracy: 0.9622 - val_loss: 0.1688 - val_accuracy: 0.9605
# Epoch 82/150
# 115/115 [==============================] - 4s 38ms/step - loss: 0.1527 - accuracy: 0.9624 - val_loss: 0.1777 - val_accuracy: 0.9580
# Epoch 83/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1513 - accuracy: 0.9629 - val_loss: 0.1720 - val_accuracy: 0.9595
# Epoch 84/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1517 - accuracy: 0.9629 - val_loss: 0.1688 - val_accuracy: 0.9593
# Epoch 85/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1509 - accuracy: 0.9627 - val_loss: 0.1700 - val_accuracy: 0.9600
# Epoch 86/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1487 - accuracy: 0.9633 - val_loss: 0.1843 - val_accuracy: 0.9565
# Epoch 87/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1496 - accuracy: 0.9631 - val_loss: 0.1705 - val_accuracy: 0.9595
# Epoch 88/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1474 - accuracy: 0.9639 - val_loss: 0.1745 - val_accuracy: 0.9590
# Epoch 89/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1449 - accuracy: 0.9643 - val_loss: 0.1706 - val_accuracy: 0.9595
# Epoch 90/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1473 - accuracy: 0.9637 - val_loss: 0.1779 - val_accuracy: 0.9582
# Epoch 91/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1420 - accuracy: 0.9651 - val_loss: 0.1858 - val_accuracy: 0.9558
# Epoch 92/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1412 - accuracy: 0.9654 - val_loss: 0.1718 - val_accuracy: 0.9589
# Epoch 93/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1403 - accuracy: 0.9651 - val_loss: 0.1681 - val_accuracy: 0.9600
# Epoch 94/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1413 - accuracy: 0.9651 - val_loss: 0.1691 - val_accuracy: 0.9603
# Epoch 95/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1412 - accuracy: 0.9650 - val_loss: 0.1789 - val_accuracy: 0.9579
# Epoch 96/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1385 - accuracy: 0.9656 - val_loss: 0.1784 - val_accuracy: 0.9577
# Epoch 97/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1394 - accuracy: 0.9658 - val_loss: 0.1654 - val_accuracy: 0.9609
# Epoch 98/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1361 - accuracy: 0.9664 - val_loss: 0.1831 - val_accuracy: 0.9574
# Epoch 99/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1360 - accuracy: 0.9661 - val_loss: 0.1697 - val_accuracy: 0.9602
# Epoch 100/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1352 - accuracy: 0.9665 - val_loss: 0.1714 - val_accuracy: 0.9608
# Epoch 101/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1337 - accuracy: 0.9666 - val_loss: 0.1752 - val_accuracy: 0.9593
# Epoch 102/150
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1369 - accuracy: 0.9662 - val_loss: 0.1665 - val_accuracy: 0.9614
# Epoch 103/150
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1332 - accuracy: 0.9667 - val_loss: 0.1844 - val_accuracy: 0.9566
# Epoch 104/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1300 - accuracy: 0.9676 - val_loss: 0.1712 - val_accuracy: 0.9600
# Epoch 105/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1298 - accuracy: 0.9677 - val_loss: 0.1677 - val_accuracy: 0.9603
# Epoch 106/150
# 115/115 [==============================] - 5s 41ms/step - loss: 0.1313 - accuracy: 0.9673 - val_loss: 0.1676 - val_accuracy: 0.9614
# Epoch 107/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1291 - accuracy: 0.9680 - val_loss: 0.1715 - val_accuracy: 0.9603
# Epoch 108/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1289 - accuracy: 0.9677 - val_loss: 0.1740 - val_accuracy: 0.9599
# Epoch 109/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1271 - accuracy: 0.9684 - val_loss: 0.1712 - val_accuracy: 0.9604
# Epoch 110/150
# 115/115 [==============================] - 5s 47ms/step - loss: 0.1266 - accuracy: 0.9686 - val_loss: 0.1673 - val_accuracy: 0.9616
# Epoch 111/150
# 115/115 [==============================] - 7s 62ms/step - loss: 0.1273 - accuracy: 0.9683 - val_loss: 0.1729 - val_accuracy: 0.9615
# Epoch 112/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1252 - accuracy: 0.9685 - val_loss: 0.1757 - val_accuracy: 0.9594
# Epoch 113/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1246 - accuracy: 0.9690 - val_loss: 0.1765 - val_accuracy: 0.9592
# Epoch 114/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1249 - accuracy: 0.9690 - val_loss: 0.1722 - val_accuracy: 0.9607
# Epoch 115/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1256 - accuracy: 0.9687 - val_loss: 0.1804 - val_accuracy: 0.9580
# Epoch 116/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1226 - accuracy: 0.9697 - val_loss: 0.1780 - val_accuracy: 0.9591
# Epoch 117/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1222 - accuracy: 0.9695 - val_loss: 0.1735 - val_accuracy: 0.9592
# Epoch 118/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1218 - accuracy: 0.9693 - val_loss: 0.1672 - val_accuracy: 0.9616
# Epoch 119/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1229 - accuracy: 0.9697 - val_loss: 0.1791 - val_accuracy: 0.9587
# Epoch 120/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1198 - accuracy: 0.9698 - val_loss: 0.1773 - val_accuracy: 0.9599
# Epoch 121/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1204 - accuracy: 0.9698 - val_loss: 0.1720 - val_accuracy: 0.9608
# Epoch 122/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1205 - accuracy: 0.9704 - val_loss: 0.1742 - val_accuracy: 0.9600
# Epoch 123/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1189 - accuracy: 0.9700 - val_loss: 0.1700 - val_accuracy: 0.9621
# Epoch 124/150
# 115/115 [==============================] - 4s 37ms/step - loss: 0.1196 - accuracy: 0.9705 - val_loss: 0.1677 - val_accuracy: 0.9617
# Epoch 125/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1173 - accuracy: 0.9707 - val_loss: 0.1820 - val_accuracy: 0.9579
# Epoch 126/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1174 - accuracy: 0.9705 - val_loss: 0.1612 - val_accuracy: 0.9629
# Epoch 127/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1147 - accuracy: 0.9712 - val_loss: 0.1678 - val_accuracy: 0.9614
# Epoch 128/150
# 115/115 [==============================] - 4s 37ms/step - loss: 0.1181 - accuracy: 0.9704 - val_loss: 0.1703 - val_accuracy: 0.9615
# Epoch 129/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1149 - accuracy: 0.9710 - val_loss: 0.1792 - val_accuracy: 0.9593
# Epoch 130/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1146 - accuracy: 0.9713 - val_loss: 0.1707 - val_accuracy: 0.9615
# Epoch 131/150
# 115/115 [==============================] - 4s 38ms/step - loss: 0.1115 - accuracy: 0.9720 - val_loss: 0.1773 - val_accuracy: 0.9603
# Epoch 132/150
# 115/115 [==============================] - 4s 36ms/step - loss: 0.1145 - accuracy: 0.9711 - val_loss: 0.1753 - val_accuracy: 0.9604
# Epoch 133/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1117 - accuracy: 0.9716 - val_loss: 0.1675 - val_accuracy: 0.9616
# Epoch 134/150
# 115/115 [==============================] - 4s 31ms/step - loss: 0.1146 - accuracy: 0.9714 - val_loss: 0.1864 - val_accuracy: 0.9564
# Epoch 135/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1121 - accuracy: 0.9719 - val_loss: 0.1855 - val_accuracy: 0.9576
# Epoch 136/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1133 - accuracy: 0.9717 - val_loss: 0.1739 - val_accuracy: 0.9600
# Epoch 137/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1137 - accuracy: 0.9715 - val_loss: 0.1739 - val_accuracy: 0.9603
# Epoch 138/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1093 - accuracy: 0.9724 - val_loss: 0.1738 - val_accuracy: 0.9605
# Epoch 139/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1087 - accuracy: 0.9723 - val_loss: 0.1626 - val_accuracy: 0.9635
# Epoch 140/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1101 - accuracy: 0.9722 - val_loss: 0.1834 - val_accuracy: 0.9577
# Epoch 141/150
# 115/115 [==============================] - 4s 37ms/step - loss: 0.1087 - accuracy: 0.9725 - val_loss: 0.1680 - val_accuracy: 0.9619
# Epoch 142/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1077 - accuracy: 0.9730 - val_loss: 0.1641 - val_accuracy: 0.9627
# Epoch 143/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1061 - accuracy: 0.9731 - val_loss: 0.1717 - val_accuracy: 0.9620
# Epoch 144/150
# 115/115 [==============================] - 4s 33ms/step - loss: 0.1087 - accuracy: 0.9729 - val_loss: 0.1688 - val_accuracy: 0.9618
# Epoch 145/150
# 115/115 [==============================] - 4s 35ms/step - loss: 0.1065 - accuracy: 0.9730 - val_loss: 0.1713 - val_accuracy: 0.9614
# Epoch 146/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1063 - accuracy: 0.9734 - val_loss: 0.1631 - val_accuracy: 0.9627
# Epoch 147/150
# 115/115 [==============================] - 4s 32ms/step - loss: 0.1045 - accuracy: 0.9738 - val_loss: 0.1586 - val_accuracy: 0.9636
# Epoch 148/150
# 115/115 [==============================] - 4s 30ms/step - loss: 0.1059 - accuracy: 0.9734 - val_loss: 0.1727 - val_accuracy: 0.9605
# Epoch 149/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1070 - accuracy: 0.9733 - val_loss: 0.1690 - val_accuracy: 0.9619
# Epoch 150/150
# 115/115 [==============================] - 4s 34ms/step - loss: 0.1035 - accuracy: 0.9739 - val_loss: 0.1628 - val_accuracy: 0.9632

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# #### Loss and Epoch graph

# %%
plt.plot(model_hist.epoch, model_hist.history['loss'])
plt.plot(model_hist.epoch, model_hist.history['val_loss'])
plt.legend(['train_loss', 'val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# #### Accuracy and Epoch graph

# %%
plt.plot(model_hist.epoch, model_hist.history['accuracy'])
plt.plot(model_hist.epoch, model_hist.history['val_accuracy'])
plt.legend(['train_accuracy', 'val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# #### Model's performance on the test data

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Loss and Accuracy: ", test_loss, test_accuracy)
# Out:
# 1205/1205 [==============================] - 23s 18ms/step - loss: 0.3042 - accuracy: 0.9402
# Loss and Accuracy:  0.30419299006462097 0.9402028918266296

# %% [markdown]
# #### Confusion matrix on the test data

# %%
# Model prediction
y_pred = model.predict(X_test)
# Post processing the results
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Creating a data frame of confusion matrix
df_confusion = pd.crosstab(y_true, y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
# Saving the csv of confusion matrix
df_confusion.to_csv('confusion_matrix.csv')

print("Confusion Matrix: ")
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 10))
plt.title("ひらがな Classifier")
plt.imshow(cm, interpolation='nearest', cmap="Blues")
# Out:
# 1205/1205 [==============================] - 14s 10ms/step
# Confusion Matrix:

# %%
idx = 0
fig, ax = plt.subplots(5, 5, figsize=(15, 8))
fig.tight_layout()
neg = X_test[np.where(y_true != y_pred)]
neg_tr = y_true[np.where(y_true != y_pred)]
neg_gr = y_pred[np.where(y_true != y_pred)]

for i in range(0, neg.shape[0], 25):
  for j in range(5):
    for k in range(5):
      ax[j, k].imshow(neg[idx], cmap="Reds")
      ax[j, k].title.set_text(f"{class_map[neg_tr[idx]]} != {class_map[neg_gr[idx]]}")
      idx += 1

  display(fig)
  plt.pause(1)
  _ = input("\n")
  clear_output(wait = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-cfb0e0b9aeeb> in <cell line: 8>()
#      15   display(fig)
#      16   plt.pause(1)
# ---> 17   _ = input("\n")
#      18   clear_output(wait = False)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### Saving the model

# %%
model.save('hiragana_classifier_v4.h5')

# %% [markdown]
# ### Download all the necessry files to local system

# %%
history_data = {
    "train_history": model_hist.history,
    "epochs": model_hist.epoch,
    "test_loss": test_loss,
    "test_accuracy": test_accuracy
}

with open("train_history.pickle", "wb") as f:
  pickle.dump(history_data, f)

# %%
# Download model
files.download('hiragana_classifier_v4.h5')
# Download model history
files.download('train_history.pickle')
# Download confusion metrix
files.download('confusion_matrix.csv')
